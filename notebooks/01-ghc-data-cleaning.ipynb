# %% [markdown]
# # Data Cleaning: Exploratory Analysis

# %%
# Built-in library
from pathlib import Path
import re
import json
from typing import Any, Optional, Union
import logging
import warnings

# Standard imports
import numpy as np
import numpy.typing as npt
from pprint import pprint
import pandas as pd
import polars as pl
from rich.console import Console
from rich.theme import Theme

custom_theme = Theme(
    {
        "info": "#76FF7B",
        "warning": "#FBDDFE",
        "error": "#FF0000",
    }
)
console = Console(theme=custom_theme)

# Visualization
import matplotlib.pyplot as plt


# Pandas settings
pd.options.display.max_rows = 1_000
pd.options.display.max_columns = 1_000
pd.options.display.max_colwidth = 600

warnings.filterwarnings("ignore")


# Black code formatter (Optional)
# %load_ext lab_black

# auto reload imports
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load Data

# %%
# Gabe Hate Corpus
fp: str = "../data/ghc_data/**/*.tsv"
ghc_data: pl.DataFrame = pl.read_csv(source=fp, separator="\t")

ghc_data.head()
# Out:
# shape: (5, 4)
# ┌───────────────────────────────────┬─────┬─────┬─────┐
# │ text                              ┆ hd  ┆ cv  ┆ vo  │
# │ ---                               ┆ --- ┆ --- ┆ --- │
# │ str                               ┆ i64 ┆ i64 ┆ i64 │
# ╞═══════════════════════════════════╪═════╪═════╪═════╡
# │ https://www.youtube.com/watch?v=… ┆ 0   ┆ 0   ┆ 0   │
# │ Very nice! I tend to get tired o… ┆ 0   ┆ 0   ┆ 0   │
# │ Watch today. https://circumcisio… ┆ 0   ┆ 0   ┆ 0   │
# │ " Thinking Venues " First Color … ┆ 0   ┆ 0   ┆ 0   │
# │ What about death penalty for per… ┆ 0   ┆ 0   ┆ 0   │
# └───────────────────────────────────┴─────┴─────┴─────┘

# %%
# Add target label
ghc_data = ghc_data.with_columns(
    hateful_or_vulgar_or_cyberbully=pl.any_horizontal("hd", "cv", "vo")
)
ghc_data.group_by("hateful_or_vulgar_or_cyberbully").agg(pl.len())
# Out:
# shape: (2, 2)
# ┌─────────────────────────────────┬───────┐
# │ hateful_or_vulgar_or_cyberbully ┆ len   │
# │ ---                             ┆ ---   │
# │ bool                            ┆ u32   │
# ╞═════════════════════════════════╪═══════╡
# │ true                            ┆ 3377  │
# │ false                           ┆ 24169 │
# └─────────────────────────────────┴───────┘

# %%
ghc_data.sample(n=20, seed=3).to_pandas()
# Out:
#                                                                                                                                                                                                                                                                                   text  \
# 0                       It's Jordanetics Week at the Daily Meme Wars, where we'll be applying Dr. Jordan Peterson's anti-nationalist philosophy of extreme atomic individualism to some of the great moments in history. Today, we have General Peterson's advice on how to win a war.
# 1   That depends what you mean by a "bad" joke.  If it just falls flat, that's in the ear of the listener.  If you think it's inherently blasphemous, I disagree.  I told it to a captain of the sodality at St. Thomas the Apostle parish this morning, and she thought it was funny.
# 2                                                                                                                                                                                                                                                       How about a Hyperloop instead?
# 3                                                                                                                                     Stein Mart cardholders could sign on to their credit card account online and also handle their - http://www.clipsit.net/www-steinmartcredit-com/
# 4                   A homosexual character hits on straight guy and then wonders why straights are mad at him, there is full on sex with the sea monster, sadistic chained torture, many abusive white males and of course evil Russians. Total NWO propaganda but filmed exquisitely.
# 5                                                                                                              Swedish Activist: "Everyone's Afraid To Be Branded A Racist" | Zero Hedge https://www.zerohedge.com/news/2018-04-23/swedish-activist-everyones-afraid-be-branded-racist
# 6                                                                                                                                                                                                                                                   Let's hope Conrad Black is right.
# 7                I had a lot of fun with her, but she ended up leaving 🙁. I would have loved to keep her, but I didn't know if she was a stray of if she was someone's pet. My cat also probably wouldn't have liked her too. Oh well, I had a lot of fun with Q'yle while she stayed.
# 8                                                                                                                                                                                                   shit is getting real right now, peoples are being murdered left, right and center.
# 9                                                                            When it comes to wearing a leather jacket, many people feel at a loss or self-conscious in the - https://www.independencebrothers.com/blog/layering-with-a-jacket #leather_jacket #fashion #jacket #style
# 10                                                                                                                                                                                           If the markets aren't concerned about Don Jr's emails then neither am I! (Dow up 128 pts)
# 11                                                                                                                                                                                                                              Commies is so 60's dood, your gonna need to catch up.
# 12                                                                                                                                                  Fortunately I had already announced this call to abandon my Star Wars fandom back in December. I hope you gentlemen will join me!
# 13                                                                                                                                                                                                   When the internet no longer brownnoses you because of your smug British accent..
# 14                                                                                                                                                                                                                            TODAY PRIMARIES IN TX , GEORGIA, ARKANSAS AND KENTUCKY.
# 15                                                                                                                                                                                                   @parscale Jim Acosta is with the protesters, not the press. https://kek.gg/u/Xw3V
# 16                                                                                                                                                                                   When you watch this, you will fully understand why we NEED Term Limits for ALL elected officials.
# 17                                                                                                                                                                                                                                      America must stop funding the United Nations.
# 18                                                                                                                                                                                                                                                   In Islam, dogs are infidels, too.
# 19                                                                                                                                                                                                                                               nigger, 3/4 of NBA players are black
#
#     hd  cv  vo  hateful_or_vulgar_or_cyberbully
# 0    0   0   0                            False
# 1    0   0   0                            False
# 2    0   0   0                            False
# 3    0   0   0                            False
# 4    1   0   0                             True
# 5    0   0   0                            False
# 6    0   0   0                            False
# 7    0   0   0                            False
# 8    0   0   1                             True
# 9    0   0   0                            False
# 10   0   0   0                            False
# 11   1   0   1                             True
# 12   0   0   0                            False
# 13   0   0   0                            False
# 14   0   0   0                            False
# 15   0   0   0                            False
# 16   0   0   0                            False
# 17   0   0   0                            False
# 18   0   0   0                            False
# 19   1   0   1                             True

# %% [markdown]
# ## To Do
#
# -  Remove punctuations.
# -  Normalize (lowercase) data.
# -  Remove stop words.
# -  Remove non letter characters (numbers, symbols, emojis, etc).
# -  Remove URLs.
# -  Remove hashtags.
# -  Remove mentions and usernames.
# -  Remove HTML tags.
# -  Implement spell correction.

# %%
ghc_data = ghc_data.select(["text", "hateful_or_vulgar_or_cyberbully"])
ghc_data.head()
# Out:
# shape: (5, 2)
# ┌───────────────────────────────────┬─────────────────────────────────┐
# │ text                              ┆ hateful_or_vulgar_or_cyberbully │
# │ ---                               ┆ ---                             │
# │ str                               ┆ bool                            │
# ╞═══════════════════════════════════╪═════════════════════════════════╡
# │ https://www.youtube.com/watch?v=… ┆ false                           │
# │ Very nice! I tend to get tired o… ┆ false                           │
# │ Watch today. https://circumcisio… ┆ false                           │
# │ " Thinking Venues " First Color … ┆ false                           │
# │ What about death penalty for per… ┆ false                           │
# └───────────────────────────────────┴─────────────────────────────────┘

# %% [markdown]
# ## Toxic Comments Classification Data

# %%
test_fp: str = "../data/toxic_comment_data/test_labels.csv"
toxic_comments_test_labels: pl.DataFrame = pl.read_csv(source=test_fp)
toxic_comments_test_labels.head()
# Out:
# shape: (5, 7)
# ┌──────────────────┬───────┬──────────────┬─────────┬────────┬────────┬───────────────┐
# │ id               ┆ toxic ┆ severe_toxic ┆ obscene ┆ threat ┆ insult ┆ identity_hate │
# │ ---              ┆ ---   ┆ ---          ┆ ---     ┆ ---    ┆ ---    ┆ ---           │
# │ str              ┆ i64   ┆ i64          ┆ i64     ┆ i64    ┆ i64    ┆ i64           │
# ╞══════════════════╪═══════╪══════════════╪═════════╪════════╪════════╪═══════════════╡
# │ 00001cee341fdb12 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            │
# │ 0000247867823ef7 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            │
# │ 00013b17ad220c46 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            │
# │ 00017563c3f7919a ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            │
# │ 00017695ad8997eb ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            │
# └──────────────────┴───────┴──────────────┴─────────┴────────┴────────┴───────────────┘

# %% [markdown]
# ### Comment
#
# - From the data dict, `-1` means it was **NOT** used for scoring/grading the performance of the model.
# - I'll drop rows with `-1` labels.

# %%
toxic_comments_test_labels = toxic_comments_test_labels.with_columns(
    contains_scoring_data=pl.mean_horizontal(
        "toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"
    ).round(2)
)
toxic_comments_test_labels.group_by("contains_scoring_data").agg(pl.len())
# Out:
# shape: (8, 2)
# ┌───────────────────────┬───────┐
# │ contains_scoring_data ┆ len   │
# │ ---                   ┆ ---   │
# │ f64                   ┆ u32   │
# ╞═══════════════════════╪═══════╡
# │ 0.17                  ┆ 1842  │
# │ 0.5                   ┆ 2081  │
# │ 0.67                  ┆ 611   │
# │ 0.0                   ┆ 57735 │
# │ -1.0                  ┆ 89186 │
# │ 0.83                  ┆ 165   │
# │ 1.0                   ┆ 14    │
# │ 0.33                  ┆ 1530  │
# └───────────────────────┴───────┘

# %%
toxic_comments_test_labels.head()
# Out:
# shape: (5, 8)
# ┌───────────────┬───────┬──────────────┬─────────┬────────┬────────┬───────────────┬───────────────┐
# │ id            ┆ toxic ┆ severe_toxic ┆ obscene ┆ threat ┆ insult ┆ identity_hate ┆ contains_scor │
# │ ---           ┆ ---   ┆ ---          ┆ ---     ┆ ---    ┆ ---    ┆ ---           ┆ ing_data      │
# │ str           ┆ i64   ┆ i64          ┆ i64     ┆ i64    ┆ i64    ┆ i64           ┆ ---           │
# │               ┆       ┆              ┆         ┆        ┆        ┆               ┆ f64           │
# ╞═══════════════╪═══════╪══════════════╪═════════╪════════╪════════╪═══════════════╪═══════════════╡
# │ 00001cee341fd ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            ┆ -1.0          │
# │ b12           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 0000247867823 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            ┆ -1.0          │
# │ ef7           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 00013b17ad220 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            ┆ -1.0          │
# │ c46           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 00017563c3f79 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            ┆ -1.0          │
# │ 19a           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 00017695ad899 ┆ -1    ┆ -1           ┆ -1      ┆ -1     ┆ -1     ┆ -1            ┆ -1.0          │
# │ 7eb           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# └───────────────┴───────┴──────────────┴─────────┴────────┴────────┴───────────────┴───────────────┘

# %%
toxic_comments_test_labels.filter(pl.col("contains_scoring_data").eq(0.17))
# Out:
# shape: (1_842, 8)
# ┌───────────────┬───────┬──────────────┬─────────┬────────┬────────┬───────────────┬───────────────┐
# │ id            ┆ toxic ┆ severe_toxic ┆ obscene ┆ threat ┆ insult ┆ identity_hate ┆ contains_scor │
# │ ---           ┆ ---   ┆ ---          ┆ ---     ┆ ---    ┆ ---    ┆ ---           ┆ ing_data      │
# │ str           ┆ i64   ┆ i64          ┆ i64     ┆ i64    ┆ i64    ┆ i64           ┆ ---           │
# │               ┆       ┆              ┆         ┆        ┆        ┆               ┆ f64           │
# ╞═══════════════╪═══════╪══════════════╪═════════╪════════╪════════╪═══════════════╪═══════════════╡
# │ 00091c35fa9d0 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ 465           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 001d739c97bc2 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ ae4           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 005f47397e07e ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ 12f           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 00b3813b966af ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ 7e8           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 00bd66c9ef023 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ f41           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ …             ┆ …     ┆ …            ┆ …       ┆ …      ┆ …      ┆ …             ┆ …             │
# │ feb3e338da2c9 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ 41e           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ ff2b1797bd553 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ 291           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ ff2b94f0258d8 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ e9f           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ ffd49b8defd06 ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 1      ┆ 0             ┆ 0.17          │
# │ 9d0           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ ffdf6854b41d9 ┆ 1     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.17          │
# │ 102           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# └───────────────┴───────┴──────────────┴─────────┴────────┴────────┴───────────────┴───────────────┘

# %%
# Drop the labels with `-1`
toxic_comments_test_labels = toxic_comments_test_labels.filter(
    pl.col("contains_scoring_data").ne(-1.0)
)
toxic_comments_test_labels.sample(n=10)
# Out:
# shape: (10, 8)
# ┌───────────────┬───────┬──────────────┬─────────┬────────┬────────┬───────────────┬───────────────┐
# │ id            ┆ toxic ┆ severe_toxic ┆ obscene ┆ threat ┆ insult ┆ identity_hate ┆ contains_scor │
# │ ---           ┆ ---   ┆ ---          ┆ ---     ┆ ---    ┆ ---    ┆ ---           ┆ ing_data      │
# │ str           ┆ i64   ┆ i64          ┆ i64     ┆ i64    ┆ i64    ┆ i64           ┆ ---           │
# │               ┆       ┆              ┆         ┆        ┆        ┆               ┆ f64           │
# ╞═══════════════╪═══════╪══════════════╪═════════╪════════╪════════╪═══════════════╪═══════════════╡
# │ 1026dc2f9e542 ┆ 1     ┆ 1            ┆ 1       ┆ 1      ┆ 1      ┆ 0             ┆ 0.83          │
# │ 485           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 7f610c7c7609d ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ bfe           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 8573f801fef78 ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ 011           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ a7e038cf7f245 ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ 9e8           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 1f1ae7e624b2e ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ 723           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 2fe07ae742f22 ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ 02e           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ da3a88c7bd16b ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ c33           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ e1951a110f0d4 ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ 1c2           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 176a3211904ad ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ ff0           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# │ 59a2c48630fdf ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             ┆ 0.0           │
# │ 3d9           ┆       ┆              ┆         ┆        ┆        ┆               ┆               │
# └───────────────┴───────┴──────────────┴─────────┴────────┴────────┴───────────────┴───────────────┘

# %%
toxic_comments_test_labels.group_by("contains_scoring_data").agg(pl.len())
# Out:
# shape: (7, 2)
# ┌───────────────────────┬───────┐
# │ contains_scoring_data ┆ len   │
# │ ---                   ┆ ---   │
# │ f64                   ┆ u32   │
# ╞═══════════════════════╪═══════╡
# │ 0.67                  ┆ 611   │
# │ 0.0                   ┆ 57735 │
# │ 0.5                   ┆ 2081  │
# │ 0.33                  ┆ 1530  │
# │ 0.83                  ┆ 165   │
# │ 1.0                   ┆ 14    │
# │ 0.17                  ┆ 1842  │
# └───────────────────────┴───────┘

# %% [markdown]
# ### Comment
#
# - `contains_scoring_data`=0.0 means NOT hateful/vulgar.
# - `contains_scoring_data`!=0.0 means hateful/vulgar.

# %%
toxic_comments_test_labels = toxic_comments_test_labels.with_columns(
    hateful_or_vulgar_or_cyberbully=pl.when(pl.col("contains_scoring_data").eq(0.0))
    .then(pl.lit(False))
    .otherwise(pl.lit(True))
).select(["id", "hateful_or_vulgar_or_cyberbully"])

toxic_comments_test_labels.sample(n=10, seed=1)
# Out:
# shape: (10, 2)
# ┌──────────────────┬─────────────────────────────────┐
# │ id               ┆ hateful_or_vulgar_or_cyberbully │
# │ ---              ┆ ---                             │
# │ str              ┆ bool                            │
# ╞══════════════════╪═════════════════════════════════╡
# │ b5db51ef0db2da17 ┆ false                           │
# │ 09fbcd08da930ed7 ┆ false                           │
# │ 2e7d4ad66d8d3c60 ┆ false                           │
# │ 574782f0c5334a33 ┆ false                           │
# │ 7967ef54886d451f ┆ true                            │
# │ f50da7f970b6bf20 ┆ true                            │
# │ 1c93d9179e473933 ┆ false                           │
# │ 68bc1bec1bb779d5 ┆ false                           │
# │ 4a2fbf9793642110 ┆ false                           │
# │ b629995dd0f0f0e1 ┆ true                            │
# └──────────────────┴─────────────────────────────────┘

# %%
fp: str = "../data/toxic_comment_data/test.csv"
toxic_comments_test_data: pl.DataFrame = pl.read_csv(source=fp)
toxic_comments_test_data.head()
# Out:
# shape: (5, 2)
# ┌──────────────────┬───────────────────────────────────┐
# │ id               ┆ comment_text                      │
# │ ---              ┆ ---                               │
# │ str              ┆ str                               │
# ╞══════════════════╪═══════════════════════════════════╡
# │ 00001cee341fdb12 ┆ Yo bitch Ja Rule is more succesf… │
# │ 0000247867823ef7 ┆ == From RfC ==                    │
# │                  ┆                                   │
# │                  ┆  The title is f…                  │
# │ 00013b17ad220c46 ┆ "                                 │
# │                  ┆                                   │
# │                  ┆  == Sources ==                    │
# │                  ┆                                   │
# │                  ┆  * Zawe Ash…                      │
# │ 00017563c3f7919a ┆ :If you have a look back at the … │
# │ 00017695ad8997eb ┆ I don't anonymously edit article… │
# └──────────────────┴───────────────────────────────────┘

# %%
# Merge the data
toxic_comments_test_data = toxic_comments_test_data.join(
    toxic_comments_test_labels, on="id"
)
toxic_comments_test_data.sample(n=10, seed=5).to_pandas()
# Out:
#                  id  \
# 0  bab1b5c4286c7364
# 1  b597d458feea1b38
# 2  56ba22742fb29153
# 3  9d2133158807b8f8
# 4  5b509d4b41475d50
# 5  bfbd18e2b7189192
# 6  8645bcd76ca16f24
# 7  bd26f3dc84c75530
# 8  c1d2d6a2bd5e9e84
# 9  5d2861330fe88700
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  comment_text  \
# 0  " \n {| class=""messagebox protected"" style=""border: 1px solid #8888aa; padding: 0px; font-size:9pt;"" \n |align=""center""|  \n |align=""left""| This user or user talk page has been temporarily protected from editing by new or unregistered users to prevent blocked users from removing warnings or introducing  vandalism to it.  (Administrators, please remember to add the user to Wikipedia:List of protected pages/User pages.) \n |} \n\n "
# 1                                                                                                                                                                                                                                                                                                                                               . One of the books is in English and the other directly claims that the translation 'Triglav cap' can be used
# 2                                                                                                                                                                                                                                                                                                                                                                                                                               Pies taste like butt holes!!!
# 3                                                                                                                                                                                                                                                                                                                                                                                                                             Filll]] 05:32, 26 December 2006
# 4                                                                                                                                                                                                                                                                                                                                                                                                                               fucks you in your ear pussies
# 5                                                                                                                                                                                                                                                                                                                                                                                                         == hey == \n\n what the fuck is your problem nigga?
# 6                                                                                                                                                                                                                                                                                                                                                                                         == Dennis Bayens == \n\n Likes to have ass sex.. \n\n  \n with men.
# 7                                                                                                                                                                                                    == Copyright tagging == \n\n When you add a db-copyvio, please indicate what the text is a copy of. If there is no url that you can use with the URL parameter, please use the edit summary, a note on the discussion page, or something. Thank you,   |
# 8                                                                                                                                              " March 2015 (UTC) \n ::::::Very cluttered? We currently show five duals. The worst case, then, is five additional rows, or a 25% increase, somewhat lower if you consider caption and heading. The way to prevent mistakes is to be careful, and any mistakes would be correctable in any case. ―  00:03, 27"
# 9                                                                                                                                                                                                                                                                                                                                             == ya what son == \n\n ya well owning with meteor shower is way more important than stupid greek history biatch
#
#    hateful_or_vulgar_or_cyberbully
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                             True
# 5                             True
# 6                             True
# 7                            False
# 8                            False
# 9                             True

# %%
# Train data
fp: str = "../data/toxic_comment_data/train.csv"
toxic_comments_train_data: pl.DataFrame = pl.read_csv(source=fp)

toxic_comments_train_data.head()
# Out:
# shape: (5, 8)
# ┌───────────────┬───────────────┬───────┬──────────────┬─────────┬────────┬────────┬───────────────┐
# │ id            ┆ comment_text  ┆ toxic ┆ severe_toxic ┆ obscene ┆ threat ┆ insult ┆ identity_hate │
# │ ---           ┆ ---           ┆ ---   ┆ ---          ┆ ---     ┆ ---    ┆ ---    ┆ ---           │
# │ str           ┆ str           ┆ i64   ┆ i64          ┆ i64     ┆ i64    ┆ i64    ┆ i64           │
# ╞═══════════════╪═══════════════╪═══════╪══════════════╪═════════╪════════╪════════╪═══════════════╡
# │ 0000997932d77 ┆ Explanation   ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             │
# │ 7bf           ┆ Why the edits ┆       ┆              ┆         ┆        ┆        ┆               │
# │               ┆ made u…       ┆       ┆              ┆         ┆        ┆        ┆               │
# │ 000103f0d9cfb ┆ D'aww! He     ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             │
# │ 60f           ┆ matches this  ┆       ┆              ┆         ┆        ┆        ┆               │
# │               ┆ backgroun…    ┆       ┆              ┆         ┆        ┆        ┆               │
# │ 000113f07ec00 ┆ Hey man, I'm  ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             │
# │ 2fd           ┆ really not    ┆       ┆              ┆         ┆        ┆        ┆               │
# │               ┆ trying t…     ┆       ┆              ┆         ┆        ┆        ┆               │
# │ 0001b41b1c6bb ┆ "             ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             │
# │ 37e           ┆ More          ┆       ┆              ┆         ┆        ┆        ┆               │
# │               ┆ I can't make  ┆       ┆              ┆         ┆        ┆        ┆               │
# │               ┆ any real sug… ┆       ┆              ┆         ┆        ┆        ┆               │
# │ 0001d958c54c6 ┆ You, sir, are ┆ 0     ┆ 0            ┆ 0       ┆ 0      ┆ 0      ┆ 0             │
# │ e35           ┆ my hero. Any  ┆       ┆              ┆         ┆        ┆        ┆               │
# │               ┆ chanc…        ┆       ┆              ┆         ┆        ┆        ┆               │
# └───────────────┴───────────────┴───────┴──────────────┴─────────┴────────┴────────┴───────────────┘

# %%
toxic_comments_train_data = toxic_comments_train_data.with_columns(
    hateful_or_vulgar_or_cyberbully=pl.mean_horizontal(
        "toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"
    ).round(2)
)
toxic_comments_train_data.group_by("hateful_or_vulgar_or_cyberbully").agg(pl.len())
# Out:
# shape: (7, 2)
# ┌─────────────────────────────────┬────────┐
# │ hateful_or_vulgar_or_cyberbully ┆ len    │
# │ ---                             ┆ ---    │
# │ f64                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ 0.67                            ┆ 1760   │
# │ 0.0                             ┆ 143346 │
# │ 0.17                            ┆ 6360   │
# │ 0.5                             ┆ 4209   │
# │ 0.83                            ┆ 385    │
# │ 0.33                            ┆ 3480   │
# │ 1.0                             ┆ 31     │
# └─────────────────────────────────┴────────┘

# %%
toxic_comments_train_data = toxic_comments_train_data.with_columns(
    hateful_or_vulgar_or_cyberbully=pl.when(
        pl.col("hateful_or_vulgar_or_cyberbully").eq(0.0)
    )
    .then(pl.lit(False))
    .otherwise(pl.lit(True))
).select(["id", "comment_text", "hateful_or_vulgar_or_cyberbully"])

toxic_comments_train_data.sample(n=10, seed=1).to_pandas()
# Out:
#                  id  \
# 0  107038eee0ac312c
# 1  cb33bcbaf63bc0a9
# 2  94c3722172bdd1a8
# 3  2ed0945470fc151e
# 4  af8388e11b823826
# 5  f93be8c67167fcfa
# 6  cbf514a48998575f
# 7  4d50db1fa0d90de8
# 8  4b410f8634d4f3ae
# 9  9af4f7245107f90d
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               comment_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       OGB \n\nHi.  I just wanted to let you know I've got plenty of non-chess edits in my history.  Just check.  Thanks.
# 1  BISE \n\nLemonMonday, I thought I would repeat here what I have already said to you on other article talk pages. As far as I am concerned the WP:BISE project is dead. I was the last person to post there on 6 February and before that it was the 3 December 2010 that there was any activity. There are many item there which have not been actioned and both the Admin's that were involved have disappeared. For my part I will continue to abide by the general WP guidelines and if I see articles that uses the term BI incorrectly I will discuss on the talk page and look at resolving the issue within W...
# 2                                                                                                                                                                                                                                                                                       should unless someone can provide additional citation. \n\nThe baboon incident, while no one seems to claim it didn't happen, may be classed as WP:FRINGE and hence non-encyclopedic example due to the fact that it was not published in a scholarly journal (notwithstanding the researcher's reputation for unethical behavior)
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  By the way Collectonian - I'm a HE not a SHE. If it makes any difference at this point.
# 4                                                                                                                                                                                        "\n\nBridget Marquardt being divorced\nAfternoon,\nU need a DIRECT link IN THE ARTICLE not on the talk page. \nPlus when u click on the 1st link 1 is taken 2 a page where 1 must make a choice; how does 1 know whether or not 2 choose m/c/p/r or w?\nMaybe if u know how 2 access the info, take a screenshot & upload it to the web, then link that. \n""snarkpit"" I dont think that is a reliable source.  70.108.133.72  "
# 5                                                                                                                                                                                                                                                                                     "\n\n Little Tidbit of information needs citation \n\n""The album's third single will be released after the album's release and Gaga has stated she wants fans to choose the third single. However, Gaga herself would like to see the next single to be 'Marry the Night.'""\n\nIs there any confirmation of this? 70.131.151.38  "
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   (The dialog would not be modal in the Raskin's sense while the user is dragging the window, for example; but that is a marginal case).
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Stop my Vandalizing??? \n\nI don't think so, stay out of my damn business you shithead or I'll kick your ass!!!
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    th 2005\nArchive 3 — November 22nd 2005 - December 29
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            "\n\n Matrixism \n\nRemoved Matrixism from this list as it does not appear to be a ""fictional"" religion.  "
#
#    hateful_or_vulgar_or_cyberbully
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# 5                            False
# 6                            False
# 7                             True
# 8                            False
# 9                            False

# %%
# Concatenate the data
toxic_comments_data: pl.DataFrame = pl.concat(
    [toxic_comments_train_data, toxic_comments_test_data], how="vertical"
)

toxic_comments_data.head()
# Out:
# shape: (5, 3)
# ┌──────────────────┬───────────────────────────────────┬─────────────────────────────────┐
# │ id               ┆ comment_text                      ┆ hateful_or_vulgar_or_cyberbully │
# │ ---              ┆ ---                               ┆ ---                             │
# │ str              ┆ str                               ┆ bool                            │
# ╞══════════════════╪═══════════════════════════════════╪═════════════════════════════════╡
# │ 0000997932d777bf ┆ Explanation                       ┆ false                           │
# │                  ┆ Why the edits made u…             ┆                                 │
# │ 000103f0d9cfb60f ┆ D'aww! He matches this backgroun… ┆ false                           │
# │ 000113f07ec002fd ┆ Hey man, I'm really not trying t… ┆ false                           │
# │ 0001b41b1c6bb37e ┆ "                                 ┆ false                           │
# │                  ┆ More                              ┆                                 │
# │                  ┆ I can't make any real sug…        ┆                                 │
# │ 0001d958c54c6e35 ┆ You, sir, are my hero. Any chanc… ┆ false                           │
# └──────────────────┴───────────────────────────────────┴─────────────────────────────────┘

# %% [markdown]
# ### Cyberbullying Data

# %%
fp: str = "../data/cyberbully_data/cyberbullying_tweets.csv"
cyberbullying_data: pl.DataFrame = pl.read_csv(source=fp)

cyberbullying_data
# Out:
# shape: (47_692, 2)
# ┌───────────────────────────────────┬────────────────────┐
# │ tweet_text                        ┆ cyberbullying_type │
# │ ---                               ┆ ---                │
# │ str                               ┆ str                │
# ╞═══════════════════════════════════╪════════════════════╡
# │ In other words #katandandre, you… ┆ not_cyberbullying  │
# │ Why is #aussietv so white? #MKR … ┆ not_cyberbullying  │
# │ @XochitlSuckkks a classy whore? … ┆ not_cyberbullying  │
# │ @Jason_Gio meh. :P  thanks for t… ┆ not_cyberbullying  │
# │ @RudhoeEnglish This is an ISIS a… ┆ not_cyberbullying  │
# │ …                                 ┆ …                  │
# │ Black ppl aren't expected to do … ┆ ethnicity          │
# │ Turner did not withhold his disa… ┆ ethnicity          │
# │ I swear to God. This dumb nigger… ┆ ethnicity          │
# │ Yea fuck you RT @therealexel: IF… ┆ ethnicity          │
# │ Bro. U gotta chill RT @CHILLShra… ┆ ethnicity          │
# └───────────────────────────────────┴────────────────────┘

# %%
cyberbullying_data.group_by("cyberbullying_type").agg(pl.len()).to_pandas()
# Out:
#     cyberbullying_type   len
# 0  other_cyberbullying  7823
# 1    not_cyberbullying  7945
# 2             religion  7998
# 3                  age  7992
# 4               gender  7973
# 5            ethnicity  7961

# %%
cyberbullying_data.filter(pl.col("cyberbullying_type").eq("religion")).to_pandas()
# Out:
#                                                                                                                                                                                                                                                                                     tweet_text  \
# 0                                                                                  Sudeep, did she invite him though? No right? Why are you getting worded up? You're okay with Parvesh Verma cause he speaks against Muslims but against an idiot like Imam because he called for chakka jam?
# 1                                                                                                                                                 @discerningmumin Islam has never been a resistance to oppression. It has always been source of oppression to both believers and non believer
# 2                                                                   Boy, your comment about Journalists wanting to keep churches closed is beneath you. As a Christian woman and human being your bosses filth is brushing off on you. Not at all unbiased and a down right lie. SHAME ON YOU.
# 3                              @ShashiTharoor @INCIndia Hindus were and are getting killed by Muslims terriorists in Kashmir. Congress mukt bharat will certainly happen if congressmen like you don’t change their idealogies and keep sounding like idiots. You actually don’t need enemies.
# 4                  White supremicists? How many do you know? There a few idiots in all races. Where is anti-semitism coming from? Dems, BLM, Antifa, Muslims. You won’t appease them by throwing white supremacy. They hate you &amp; want to destroy Israel &amp; all Jews &amp; you know it.
# ...                                                                                                                                                                                                                                                                                        ...
# 7993  Can you imagine if Christians came together like that 5 times a day? As long as New Yorkers continue to vote Corrupt Dirtbags into office this situation will only get worse.Ppl need to realize Radical Muslims dont give a damn about Americans regardless of which party you support.
# 7994                                                                                                                                So how to support justice from the initial problem? It morphed into all that and became radical. People and Christians want to support legitimate justice.
# 7995                                                                                                                                              RT @TRobinsonNewEra: If you harbour any doubts about what % Muslims believe sharia note this data 36%/310.5 million nontrivial http://t.co/…
# 7996                                                                                                                                               @dankmtl @PeaceNotHate_ One thing about Muslims, they want to exterminate everyone who is not a Muslim. They are doing it around the world.
# 7997   Does the Quran precludes women from human rights or adherents did? What’s clear is both religions limit the place of the woman spiritually and physically, whatever the Christian woman has achieved today in terms of liberation is just social rebellion against biblical injunctions
#
#      cyberbullying_type
# 0              religion
# 1              religion
# 2              religion
# 3              religion
# 4              religion
# ...                 ...
# 7993           religion
# 7994           religion
# 7995           religion
# 7996           religion
# 7997           religion
#
# [7998 rows x 2 columns]

# %%
cyberbullying_data.filter(
    pl.col("cyberbullying_type").eq("not_cyberbullying")
).to_pandas()
# Out:
#                                                                                                                         tweet_text  \
# 0                                                                    In other words #katandandre, your food was crapilicious! #mkr
# 1              Why is #aussietv so white? #MKR #theblock #ImACelebrityAU #today #sunrise #studio10 #Neighbours #WonderlandTen #etc
# 2                                                                     @XochitlSuckkks a classy whore? Or more red velvet cupcakes?
# 3                          @Jason_Gio meh. :P  thanks for the heads up, but not too concerned about another angry dude on twitter.
# 4                          @RudhoeEnglish This is an ISIS account pretending to be a Kurdish account.  Like Islam, it is all lies.
# ...                                                                                                                            ...
# 7940                                                                                          I don't know what I want to wear#ugh
# 7941                                                                 Argh another round of instant restaurants....over it!!!! #mkr
# 7942                                                  Teacher sets up new charity to tackle anti-gay bullying  http://t.co/3GCzf1x
# 7943             I can barely tolerate Kat and Andre, Katie and Nikki are annoying but I'd rather see them than Kat and Andre #mkr
# 7944  People keep asking me about the stuff I posted about that site &amp; ties to rooshv. http://t.co/eEDxrUjDxE dun dun DUNNNNNN
#
#      cyberbullying_type
# 0     not_cyberbullying
# 1     not_cyberbullying
# 2     not_cyberbullying
# 3     not_cyberbullying
# 4     not_cyberbullying
# ...                 ...
# 7940  not_cyberbullying
# 7941  not_cyberbullying
# 7942  not_cyberbullying
# 7943  not_cyberbullying
# 7944  not_cyberbullying
#
# [7945 rows x 2 columns]

# %%
cyberbullying_data = cyberbullying_data.with_columns(
    hateful_or_vulgar_or_cyberbully=pl.when(
        pl.col("cyberbullying_type").eq("not_cyberbullying")
    )
    .then(pl.lit(False))
    .otherwise(pl.lit(True))
).select(["tweet_text", "cyberbullying_type"])

cyberbullying_data.sample(n=10, seed=1).to_pandas()
# Out:
#                                                                                                                                                                                                                                                                      tweet_text  \
# 0                                                                                                                  Bitches Like there was this girl in high school who bullied me and then we became moms at the same time so now she thinks we can be friends like go away lol
# 1                                                                                                                                                                        @cortanav yo, you're enforcing at PAX this year, right? can you find a person? https://t.co/uKxe6fVVfc
# 2                                                                                                                                                                        RT @Jean_D_Almeida: Im not sexist but its just amazing when a woman knows how to cook! #lovrmesomefood
# 3                                                                                              @ZakaWaqar kaash kbhi ksi basic rights k lye is generation ko D Chowk pe laya hota... Shame on you idiot. People like you are curse on the Muslim nation. #ChickenDinnerAtDChowk
# 4                                                                                        Minnesota this is what happens maybe you idiots that vote liberal will understand now and you Voted a Muslim radical in the the House of Representatives you get what's coming to you!
# 5                                                                                                Fucking moral relativist bullshit. Fucking weak ass nigger culture. Fucking Jew ass ruling class. Fucking dumb sedated docile life style. Fucking demon pawns everywhere. Fuck
# 6       Black. White. Hispanic. Muslim. Christian. Woman. Man. ... As long as he/she is capable and is doing right by/for people, race or belief don't matter. It must be 200% better than that villain (+ administration) that is in the WH right now. #VoteBidenToSaveAmerica
# 7                                                                                                                                                                                                         Miley Cyrus makes date rape joke onstage at GAY http://dlvr.it/5f1HTS
# 8                                                                                                                                           My uncle doesn't rape me fucking good for him, well done for being a basic mildly decent human being, want a medal? #Blameonenotall
# 9  The idiot knows nothing...in Israel all civil ceremonies are legal as with all other modern countries ...if you want an orthodox Jewish or Muslim wedding with another faith An iman or rabbi won’t marry the two however that doesn’t stop a legal civil one from occurring
#
#     cyberbullying_type
# 0                  age
# 1    not_cyberbullying
# 2               gender
# 3             religion
# 4             religion
# 5            ethnicity
# 6             religion
# 7               gender
# 8  other_cyberbullying
# 9             religion
